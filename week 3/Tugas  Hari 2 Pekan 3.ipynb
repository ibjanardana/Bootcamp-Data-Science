# %% [markdown]
# <h2>Soal 1:</h2>
#
# Dengan menggunakan data di bawah ini, plot kan data tersebut kemudian custom sehingga memiliki result seperti yang di harapkan :
#
# note: warna terdiri dari warna Hijau, kuning, Biru, dan Merah

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.linspace(-10, 10, 100)
cos = np.cos(x)
cos3 = np.cos(x)*3
sin = np.sin(x-90)
sin2 = np.sin(x)*2

# %%
#code here
fig,ax = plt.subplots(figsize=(8.1,5))
ax.plot(x, cos, color='r', label='Cosx')
ax.plot(x, cos3, color='g', linestyle='--', label='3 Cosx')
ax.plot(x, sin, color='b', linestyle='-.', label='Sin(x-90)')
ax.plot(x, sin2, color='y', linestyle='none', marker='x', label='2 Sinx')
plt.title(label='Grafik Cos Sin')
plt.legend(loc='center')
plt.xlabel(xlabel='X-Axis Label')
plt.ylabel(ylabel='Y-Axis Label')
plt.show()

# %% [markdown]
# Expected Result:
#
# ![alt text](https://drive.google.com/uc?id=1XRcfWyiWLDmriw7s7U4fTn5Gs6s2qf5o)
